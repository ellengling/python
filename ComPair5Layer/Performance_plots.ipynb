# %%
# %matplotlib inline

import FigureOfMeritPlotter
data = FigureOfMeritPlotter.parseEventAnalysisLogs(directory="/Volumes/AMEGO/COMPAIRPATH/python/",
                                                   triggerEfficiencyFilename='/Volumes/AMEGO/COMPAIRPATH/python/TriggerEfficiency.txt')
# Out:
# Parsing: /Volumes/AMEGO/COMPAIRPATH/python//FarFieldPointSource_1.000MeV_Cos1.0.inc1.id1.log
# Parsing: /Volumes/AMEGO/COMPAIRPATH/python//FarFieldPointSource_1.500MeV_Cos1.0.inc1.id1.log
# Parsing: /Volumes/AMEGO/COMPAIRPATH/python//FarFieldPointSource_0.750MeV_Cos1.0.inc1.id1.log
# Parsing: /Volumes/AMEGO/COMPAIRPATH/python//FarFieldPointSource_10.000MeV_Cos1.0.inc1.id1.log
# Parsing: /Volumes/AMEGO/COMPAIRPATH/python//FarFieldPointSource_5.000MeV_Cos1.0.inc1.id1.log
# Parsing: /Volumes/AMEGO/COMPAIRPATH/python//FarFieldPointSource_0.500MeV_Cos1.0.inc1.id1.log
# Parsing: /Volumes/AMEGO/COMPAIRPATH/python//FarFieldPointSource_100.000MeV_Cos1.0.inc1.id1.log
# Parsing: /Volumes/AMEGO/COMPAIRPATH/python//FarFieldPointSource_500.000MeV_Cos1.0.inc1.id1.log

# %%
reload(FigureOfMeritPlotter)
FigureOfMeritPlotter.plotEnergyResolution(data,angleSelections=[1.0],
                                           save=True, collapse=False)
# Out:
# (array([  0.5 ,   0.75,   1.  ,   1.5 ,   5.  ,  10.  , 100.  , 500.  ]),
#  array([0.01266355, 0.01200954, 0.01047434, 0.01049748, 0.01561047]),
#  array([0.28299447, 0.14282285, 0.15865139, 0.17630468]))

# %%
reload(FigureOfMeritPlotter)
FigureOfMeritPlotter.plotAllSourceSensitivities(data,angleSelection=1.0, plotIdeal=True,save=True)
# Out:
# (array([  0.5 ,   0.75,   1.  ,   1.5 ,   5.  ,  10.  , 100.  , 500.  ]),
#  array([4.06638628e-04, 3.87744094e-04, 2.60247957e-04, 2.42461704e-04,
#         1.01618098e-04, 7.77782007e-05, 2.41600822e-05, 3.18335524e-05]))

# %%
reload(FigureOfMeritPlotter)
FigureOfMeritPlotter.plotEffectiveArea(data,angleSelections=[1.0],ylog=True, 
                                       collapse=False, ideal=True, save=True)
# Out:
# (array([0.02050716, 0.02304123, 0.03071159, 0.04930829, 0.14894978,
#         0.2372914 ,        nan,        nan]),
#  array([0.02192258, 0.07336985, 0.14427535, 0.26810147, 0.88398814,
#         1.15199398,        nan,        nan]),
#  array([        nan,         nan,  0.02533005,  0.06417961,  0.13018079,
#          0.28540058,  5.09230572, 13.65712101]),
#  array([  0.5 ,   0.75,   1.  ,   1.5 ,   5.  ,  10.  , 100.  , 500.  ]))

# %%
reload(FigureOfMeritPlotter)
FigureOfMeritPlotter.plotAngularResolution(data,angleSelections=[1.0],
                                           save=True, collapse=False)
# Out:
# (array([  0.5 ,   0.75,   1.  ,   1.5 ,   5.  ,  10.  , 100.  , 500.  ]),
#  array([6.15625959, 9.85852445, 8.65909043, 9.89799592, 9.89570889,
#         8.29611571,        nan,        nan]),
#  array([       nan,        nan,        nan,        nan, 7.52936943,
#         6.48373089, 2.55756529, 1.67477985]))
